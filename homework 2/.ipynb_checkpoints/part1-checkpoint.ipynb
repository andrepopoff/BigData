# %% [markdown]
# ## Сгруппируйте данные по полу и году и визуализируйте общую динамику рождаемости обоих полов

# %%
import pandas as pd
import matplotlib.pyplot as plt 
from os.path import join
# %matplotlib inline

directory = 'babynames'
df = pd.DataFrame()

for i in range(1880, 2011):
    file = 'yob{}.txt'.format(i)
    new_df = pd.read_csv(join(directory, file), names=['name', 'sex', 'numbers', 'year'])
    new_df['year'] = i
    df = df.append(new_df)

df
# Out:
#             name sex  numbers  year
# 0           Mary   F     7065  1880
# 1           Anna   F     2604  1880
# 2           Emma   F     2003  1880
# 3      Elizabeth   F     1939  1880
# 4         Minnie   F     1746  1880
# 5       Margaret   F     1578  1880
# 6            Ida   F     1472  1880
# 7          Alice   F     1414  1880
# 8         Bertha   F     1320  1880
# 9          Sarah   F     1288  1880
# 10         Annie   F     1258  1880
# 11         Clara   F     1226  1880
# 12          Ella   F     1156  1880
# 13      Florence   F     1063  1880
# 14          Cora   F     1045  1880
# 15        Martha   F     1040  1880
# 16         Laura   F     1012  1880
# 17        Nellie   F      995  1880
# 18         Grace   F      982  1880
# 19        Carrie   F      949  1880
# 20         Maude   F      858  1880
# 21         Mabel   F      808  1880
# 22        Bessie   F      794  1880
# 23        Jennie   F      793  1880
# 24      Gertrude   F      787  1880
# 25         Julia   F      783  1880
# 26        Hattie   F      769  1880
# 27         Edith   F      768  1880
# 28        Mattie   F      704  1880
# 29          Rose   F      700  1880
# ...          ...  ..      ...   ...
# 33808    Zaviyon   M        5  2010
# 33809   Zaybrien   M        5  2010
# 33810   Zayshawn   M        5  2010
# 33811     Zayyan   M        5  2010
# 33812       Zeal   M        5  2010
# 33813     Zealan   M        5  2010
# 33814   Zecharia   M        5  2010
# 33815   Zeferino   M        5  2010
# 33816   Zekariah   M        5  2010
# 33817       Zeki   M        5  2010
# 33818     Zeriah   M        5  2010
# 33819     Zeshan   M        5  2010
# 33820     Zhyier   M        5  2010
# 33821   Zildjian   M        5  2010
# 33822       Zinn   M        5  2010
# 33823     Zishan   M        5  2010
# 33824      Ziven   M        5  2010
# 33825      Zmari   M        5  2010
# 33826      Zoren   M        5  2010
# 33827     Zuhaib   M        5  2010
# 33828     Zyeire   M        5  2010
# 33829    Zygmunt   M        5  2010
# 33830   Zykerion   M        5  2010
# 33831      Zylar   M        5  2010
# 33832      Zylin   M        5  2010
# 33833    Zymaire   M        5  2010
# 33834     Zyonne   M        5  2010
# 33835  Zyquarius   M        5  2010
# 33836      Zyran   M        5  2010
# 33837      Zzyzx   M        5  2010
#
# [1690784 rows x 4 columns]

# %%
df2 = df.groupby(['year', 'sex'], as_index=False).sum()
df2.head()
# Out:
#    year sex  numbers
# 0  1880   F    90993
# 1  1880   M   110493
# 2  1881   F    91955
# 3  1881   M   100748
# 4  1882   F   107851

# %%
df2.groupby('year').sum().plot(subplots=True, rot=0, sharey=True, legend=True, title='Общая динамика рождаемости')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x10f44c2e8>],
#       dtype=object)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

df2[df2['sex'].values == 'F'].plot(x='year', title='Динамика рождаемости девочек', colormap='Accent', ax=axes[0], figsize=(10, 5))
df2[df2['sex'].values == 'M'].plot(x='year', title='Динамика рождаемости мальчиков', ax=axes[1], figsize=(10, 5))

fig.tight_layout()

# %% [markdown]
# ## Найдите самые популярные имена за всю историю

# %%
df3 = df.groupby('name', as_index=False).sum().sort_values('numbers', ascending=False)
df3[['name', 'numbers']].head(10)
# Out:
#           name  numbers
# 34995    James  5072771
# 38950     John  5061897
# 68084   Robert  4788050
# 57277  Michael  4265373
# 55384     Mary  4119074
# 85076  William  4002392
# 19333    David  3538748
# 67665  Richard  2552269
# 39629   Joseph  2529809
# 14390  Charles  2347703

# %% [markdown]
# ## Разбейте весь временной промежуток в данных на 10 частей и для каждой найдите самое популярное имя каждого пола. Для каждого найденного имени визуализируйте его динамику за все время

# %%
import numpy as np

years = np.linspace(1880, 2010, len(range(1880, 2011)), dtype=int)
top_names = {}
df6 = pd.DataFrame()
period = int(len(years) / 10)

for i in range(0, len(years), period):
    if years[i] != years[-1]:
        df4 = df[df['year'].isin(years[i:i + period])]
        df5 = df4.groupby(['sex', 'name'], as_index=False).sum().sort_values(['sex', 'numbers'], ascending=False)
        male = df5[df5['sex'].values == 'M'].iloc[0]['name']
        female = df5[df5['sex'].values == 'F'].iloc[0]['name']
        new_df = pd.DataFrame({'F': female, 'M': male}, index=['{}-{}'.format(years[i], years[i + period - 1])])
        df6 = df6.append(new_df)

df6
# Out:
#                   F        M
# 1880-1892      Mary     John
# 1893-1905      Mary     John
# 1906-1918      Mary     John
# 1919-1931      Mary   Robert
# 1932-1944      Mary   Robert
# 1945-1957     Linda    James
# 1958-1970      Lisa  Michael
# 1971-1983  Jennifer  Michael
# 1984-1996   Jessica  Michael
# 1997-2009     Emily    Jacob

# %%
top_female_names = np.unique(df6['F'].values)

for name in top_female_names:
    df7 = df[df['name'] == name]
    df7[df7['sex'].values == 'F'].plot(x='year', title=name)

# %%
top_male_names = np.unique(df6['M'].values)

for name in top_male_names:
    df7 = df[df['name'] == name]
    df7[df7['sex'].values == 'M'].plot(x='year', title=name)

# %% [markdown]
# ## Для каждого года рассчитайте сколько имен покрывают 50% людей, визуализируйте (мы увидим разнообразие имен за каждый год)

# %%
# Группировка: год - общее кол-во людей

total_people = df2.groupby('year', as_index=False).sum()

# Группировка: год - популярные имена

popular_names = df.groupby(['year', 'name'], as_index=False).sum().sort_values(['year', 'numbers'], ascending=False)

df8 = pd.DataFrame()
popular_names.iloc[0].values

total_people['year'].min()

for year in range(total_people['year'].max(), total_people['year'].min() - 1):
    print(year)
#     total_people[total_people['year'].values == ]

# for i in popular_names.values:
#     print(i)
